# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait

from selenium import webdriver
import urllib.request
import socket
import urllib.error

import time
import csv
import random
import threading as th
from selenium import webdriver
from selenium.webdriver.common.proxy import Proxy, ProxyType
import time


options = webdriver.ChromeOptions()

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 103.0.5060
# [WDM] - Get LATEST chromedriver version for 103.0.5060 google-chrome
# [WDM] - About to download new driver from https://chromedriver.storage.googleapis.com/103.0.5060.134/chromedriver_win32.zip
# [WDM] - Driver has been saved in cache [C:\Users\asd_v\.wdm\drivers\chromedriver\win32\103.0.5060.134]

# %%
# link = 'https://www.freeproxylists.net/?page=1'
# driver.get(link)
# freeproxylists_df = pd.DataFrame(columns=["protocol",'proxy'])
# time.sleep(1)
# last_page = driver.find_elements(By.XPATH,value = '/html/body/div[1]/div[2]/div[2]/a')[-2].text

# %%
# link = 'https://www.freeproxylists.net/?page=1'
# driver.get(link)
# freeproxylists_df = pd.DataFrame(columns=["protocol",'proxy'])
# time.sleep(1)
# last_page = driver.find_elements(By.XPATH,value = '/html/body/div[1]/div[2]/div[2]/a')[-2].text
# for i in range(1,int(last_page)+1):
#     link = f'https://www.freeproxylists.net/?page={i}'
#     driver.get(link)
#     time.sleep(2)
#     IP  = [s.text for s in driver.find_elements(By.XPATH,value = '/html/body/div[1]/div[2]/table/tbody/tr/td[1]')]
#     Port  =[s.text for s in driver.find_elements(By.XPATH,value = '/html/body/div[1]/div[2]/table/tbody/tr/td[2]')]
#     Protocol  = [s.text for s in driver.find_elements(By.XPATH,value = '/html/body/div[1]/div[2]/table/tbody/tr/td[3]')]
#     while True:
#         try:
#             IP.remove('')
#         except:
#             break
        
#     proxy = [i+":"+y for i , y in zip(IP,Port)]
#     proxy.pop(0)
#     Protocol.pop(0)
#     new_df = pd.DataFrame(list(zip(proxy, Protocol)),columns=["protocol",'proxy'])
#     freeproxylists_df = pd.concat([freeproxylists_df, new_df])
#     print(len(freeproxylists_df))
# #     df = pd.DataFrame(columns=["protocol",'proxy'])

# #     df[df.columns[0]] = Protocol
# #     df[df.columns[1]] = proxy
# #     df.head()
# freeproxylists_df.to_csv('freeproxylists_df.csv')
# freeproxylists_df
# Out:
# 50
# 100
# 150
# 200
# 249
#                 protocol  proxy
# 0     183.215.172.2:9091   HTTP
# 1    190.26.201.194:8080  HTTPS
# 2       45.230.225.1:666   HTTP
# 3      103.148.72.106:80   HTTP
# 4        8.219.97.248:80  HTTPS
# ..                   ...    ...
# 44    194.233.88.38:3128  HTTPS
# 45     223.85.12.16:2222   HTTP
# 46     89.38.96.219:3128  HTTPS
# 47   140.227.69.124:3180  HTTPS
# 48  221.193.240.115:9091   HTTP
#
# [249 rows x 2 columns]

# %%
# link = 'https://hidemy.name/en/proxy-list/'
# driver.get(link)
# hidemy_df = pd.DataFrame(columns=["protocol",'proxy'])
# time.sleep(1)
# last_page = driver.find_element(By.XPATH,value = '/html/body/div[1]/div[4]/div/div[5]/ul/li[9]/a').text
# for i in range(int(last_page)):
#     time.sleep(2)
#     IP  = [s.text for s in driver.find_elements(By.XPATH,value = '/html/body/div[1]/div[4]/div/div[4]/table/tbody/tr/td[1]')]
#     Port  =[s.text for s in driver.find_elements(By.XPATH,value = '/html/body/div[1]/div[4]/div/div[4]/table/tbody/tr/td[2]')]
#     Protocol  = [s.text for s in driver.find_elements(By.XPATH,value = '/html/body/div[1]/div[4]/div/div[4]/table/tbody/tr/td[5]')]
#     while True:
#         try:
#             IP.remove('')
#         except:
#             break
        
#     proxy = [i+":"+y for i , y in zip(IP,Port)]
#     proxy.pop(0)
#     Protocol.pop(0)
#     new_df = pd.DataFrame(list(zip(proxy, Protocol)),columns=["protocol",'proxy'])
#     hidemy_df = pd.concat([hidemy_df, new_df])
#     print(len(hidemy_df))
#     #next page
#     driver.find_elements(By.XPATH,value = '/html/body/div[1]/div[4]/div/div[5]/ul/li/a')[-1].click()
# #     df = pd.DataFrame(columns=["protocol",'proxy'])

# #     df[df.columns[0]] = Protocol
# #     df[df.columns[1]] = proxy
# #     df.head()
# hidemy_df.to_csv('hidemy_df.csv')
# hidemy_df
# Out:
# 63
# 126
# 189
# 252
# 315
# 378
# 441
# 504
# 567
# 630
# 693
# 756
# 819
# 882
# 945
# 1008
# 1071
# 1134
# 1197
# 1260
# 1323
# 1386
# 1449
# 1512
# 1575
# 1638
# 1701
# 1764
# 1827
# 1890
# 1953
# 2016
# 2079
# 2142
# 2205
# 2268
# 2331
# 2394
# 2457
# 2520
# 2583
# 2646
# 2709
# 2772
# 2835
# 2898
# 2961
# 3024
# 3087
# 3150
# 3213
# 3276
# 3339
# 3402
# 3465
# 3528
# 3591
# 3654
# 3717
# 3780
# 3843
# 3906
# 3969
# 4032
# 4095
# 4158
# 4221
# 4284
# 4347
# 4410
# 4473
# 4536
# 4599
# 4662
# 4725
# 4788
# 4851
# 4914
# 4977
# 5040
# 5103
# 5166
# 5229
# 5292
# 5355
# 5418
# 5481
# 5544
# 5607
# 5670
# 5733
# 5796
# 5859
# 5922
# 5985
# 6048
# 6111
# 6174
# 6237
# 6300
# 6363
# 6426
# 6489
# 6552
# 6615
# 6678
# 6741
# 6804
# 6867
# 6930
# 6993
# 7056
# 7119
# 7182
# 7245
# 7308
# 7371
# 7434
# 7497
# 7560
# 7623
# 7686
# 7749
# 7812
# 7875
# 7938
# 8001
# 8064
# 8127
# 8190
# 8253
# 8316
# 8379
# 8442
# 8505
# 8568
# 8631
# 8694
# 8757
# 8820
# 8883
# 8946
# 9009
# 9072
# 9135
# ...

# %%
# link = 'https://free-proxy-list.net/'
# driver.get(link)
# free_proxy_df = pd.DataFrame(columns=["protocol",'proxy'])

# # last_page = driver.find_element(By.XPATH,value = '/html/body/div[1]/div[4]/div/div[5]/ul/li[9]/a').text

# time.sleep(2)
# IP  = [s.text for s in driver.find_elements(By.XPATH
#     ,value = '//*[@id="list"]/div/div[2]/div/table/tbody/tr/td[1]')]
# Port  =[s.text for s in driver.find_elements(By.XPATH
#      ,value = '//*[@id="list"]/div/div[2]/div/table/tbody/tr/td[2]')]
# Protocol  = [s.text for s in driver.find_elements(By.XPATH
#     ,value = '//*[@id="list"]/div/div[2]/div/table/tbody/tr/td[7]')]
# Protocol = ['HTTPS' if x == 'yes' else 'HTTP' for x in Protocol]
# while True:
#     try:
#         IP.remove('')
#     except:
#         break

# proxy = [i+":"+y for i , y in zip(IP,Port)]
# #     proxy.pop(0)
# #     Protocol.pop(0)
# new_df = pd.DataFrame(list(zip(proxy, Protocol)),columns=["protocol",'proxy'])
# free_proxy_df = pd.concat([free_proxy_df, new_df])
# print(len(free_proxy_df))
#     #next page
# #     driver.find_elements(By.XPATH,value = '/html/body/div[1]/div[4]/div/div[5]/ul/li/a')[-1].click()
# #     df = pd.DataFrame(columns=["protocol",'proxy'])

# #     df[df.columns[0]] = Protocol
# #     df[df.columns[1]] = proxy
# #     df.head()
# free_proxy_df.to_csv('free_proxy_df.csv')
# free_proxy_df
# Out:
# 300
#                 protocol proxy
# 0      80.48.119.28:8080  HTTP
# 1     66.29.154.103:3128  HTTP
# 2     103.232.215.194:80  HTTP
# 3       169.57.1.85:8123  HTTP
# 4     66.29.154.105:3128  HTTP
# ..                   ...   ...
# 295  154.92.112.216:5237  HTTP
# 296    61.29.96.146:8000  HTTP
# 297  216.176.187.99:8886  HTTP
# 298  118.67.219.153:8080  HTTP
# 299  50.235.247.114:8085  HTTP
#
# [300 rows x 2 columns]

# %%
# import pandas as pd
# from selenium import webdriver
# from selenium.webdriver.chrome.options import Options
# from selenium.webdriver.common.keys import Keys
# from selenium.webdriver.common.by import By
# from selenium.webdriver.chrome.service import Service
# from webdriver_manager.chrome import ChromeDriverManager
# from selenium.webdriver.support.ui import Select
# from selenium.webdriver.support.ui import WebDriverWait

# from selenium import webdriver

# import time
# import csv
# import random
# import threading as th

# # PROXY = "11.456.448.110:8080"
# # chrome_options.add_argument('--proxy-server=%s' % PROXY)
# # options = webdriver.ChromeOptions()
# # # options.add_argument('--proxy-server=%s' % PROXY)
# # driver = webdriver.Chrome()

# #proxy server definition
# from selenium import webdriver
# from selenium.webdriver.common.proxy import Proxy, ProxyType
# import time

# # change 'ip:port' with your proxy's ip and port
# #139.99.237.62	80
# proxy_ip_port = '245.173.231.193:8080'

# proxy = Proxy()
# proxy.proxy_type = ProxyType.MANUAL
# proxy.http_proxy = proxy_ip_port
# proxy.ssl_proxy = proxy_ip_port

# capabilities = webdriver.DesiredCapabilities.CHROME
# proxy.add_to_capabilities(capabilities)
# # replace 'your_absolute_path' with your chrome binary absolute path
# driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()),desired_capabilities=capabilities)

# driver.get('http://whatismyipaddress.com')

# # time.sleep(8)

# %%
import pandas as pd

# %%
free_proxy_df = pd.read_csv('free_proxy_df.csv')
freeproxylists_df = pd.read_csv('freeproxylists_df.csv')

# %%
final_df  = pd.concat([free_proxy_df,freeproxylists_df])

# %%
import urllib.request
import socket
import urllib.error

def is_bad_proxy(pip):    
    try:        
        proxy_handler = urllib.request.ProxyHandler({'https': pip})        
        opener = urllib.request.build_opener(proxy_handler)
        opener.addheaders = [('User-agent', 'Mozilla/5.0')]
        urllib.request.install_opener(opener)        
        sock=urllib.request.urlopen('https://www.google.com/')  
    except urllib.error.HTTPError as e:        
#         print('Error code: ', e.code)
        return e.code
    except Exception as detail:

#         print( "ERROR:", detail)
        return 1
    return 0

# %%
proxyList = final_df[final_df['proxy']=='HTTPS']['protocol'].tolist()

# %%
proxyList = ['8.219.97.248:80']

# %%
len(proxyList)
# Out:
# 76

# %%
workin_list = []
for item in proxyList:
    if is_bad_proxy(item):
        print ("Bad Proxy", item)
    else:
        workin_list.append(item)
        print (item, "is working")
# Out:
# 8.219.97.248:80 is working
